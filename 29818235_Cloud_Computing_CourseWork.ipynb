# %%
#Name: Alexis Courtois-Gritsanchouk
#ID: 29818235

#used for sleep function
import time
#from timer import Timer
#used for exiting program
import sys
#to manipulate data as a dataframe
import pandas as pd
#to preprosess data
from sklearn import preprocessing
#to visualise data and results
import matplotlib.pyplot as plt
#for visualisations
import seaborn as sns #Visualization
#to convert from integers to strings
from sklearn.preprocessing import LabelEncoder
#classification reports confusion matrixs etc.
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, auc, roc_curve
import numpy as np
#import dataset
dataPassengers = pd.read_csv('AComp_Passenger_data_no_error(1).csv')
dataAirport = pd.read_csv('Top30_airports_LatLong(1).csv')

print("Displaying Passengers Data:")
display(dataPassengers)
print("\nDisplaying Airports Data:")
display(dataAirport)

list1 = dataPassengers["From Airport Acronym"]
#list1.pop(0)                #used to check an see if the error handling section of code works correctly 
#list1[5] = "NaN"            #used to check an see if the error handling section of code works correctly
print("\n Airport Acronym Column:\n", list1)

list2 = dataPassengers["Passenger ID"]
print("\n Passengers ID Column:\n", list2)

data_pairs = []

file_object = open("CloudComputing.txt","w+")




def mapper(value):                                                   #for mapping
    for item in value:                                               #for each item in the list
        if len(item) == 0 or item == "NaN" or item == "NAN" or item == "Nan" or item == "nan" or item == "naN": #checking to see if all values have data
            print("\nThere Are NAN's In The Data Given, Closing Program\n")
            time.sleep(5)
            sys.exit()
        else:
            temp = item +' ' + str(1)                                #take each item and add one on the end
            data_pairs.append(temp)                                  #append (add) each item together
    data_pairs.sort()                                                #sort in alphabetical order
    print("\n All Individual Values Found In List: \n", data_pairs)  #print list of values
   

def reducer(value):                                                                      #for reducing
    data_pairs_final = list(dict.fromkeys(data_pairs))                                   #create only unique value list
    print("\n Final Unique Values List: \n", data_pairs_final)                           #printing unique values
    print("\n Final Unique Values List Length: \n", len(data_pairs_final))               #printing length of unique values
    print("\n Final Reduced List Of All Unique Values And The Number Of Each One: \n")
    for item in data_pairs_final:                                                        #for each item in list
        count = data_pairs.count(item)                                                   #count how many are the same
        Final_List=item.split(' ')[0] + ":" + str(count)                             #keep only one of each value (unique) and add the number of counts of each unique value
        file_object.write("\n")
        file_object.write(Final_List)                                                #saving output to external .txt file also
        print(Final_List)                                                            #printing final list of all unique values



if __name__ == '__main__':
    start = time.time()
    mapper(list1)
    end = time.time()
    Map1 = end - start
    print("\nTime It Took For Mapper Function To Calculate In Seconds: ", Map1)

    start2 = time.time()
    reducer(list1)
    end2 = time.time()
    Reduce1 = end2 - start2
    print("Time It Took For Reducer Function To Calculate In Seconds: ", Reduce1)
    
    print("\n")
    data_pairs = []
    file_object.write("\n")
    
    start3 = time.time()
    mapper(list2)
    end3 = time.time()
    Map2 = end3 - start3
    print("\nTime It Took For Mapper Function To Calculate In Seconds: ", Map2)

    start4 = time.time()
    reducer(list2)
    end4 = time.time()
    Reduce2 = end4 - start4
    print("\nTime It Took For Reducer Function To Calculate In Seconds: ", Reduce2)

    
    ################ using seaborn unique function to cross reference with own created map reduce program to check results ################ 
    print("\n using seaborn unique to cross reference with own created map reduce program: \n")
    start5 = time.time()
    print(dataPassengers['From Airport Acronym'].unique()) #what unique values in From Airport Acronym column
    end5 = time.time()
    MapSeaborn1 = end5 - start5
    print("Time It Took For Unique Function Mapping from seaborn To Calculate In Seconds: ", MapSeaborn1)
    print("")
    start6 = time.time()
    print(dataPassengers.groupby('From Airport Acronym').size()) #number of unique values in From Airport Acronym column 
    end6 = time.time()
    ReduceSeaborn1 = end6 - start6
    print("Time It Took For Reducer from seaborn To Calculate In Seconds: ", ReduceSeaborn1)
    f2 = plt.figure(figsize=(15,8))
    sns.countplot(dataPassengers['From Airport Acronym'],label="Count") #displaying bar chart with counts of each unique value

    print("\n")
    start7 = time.time()
    print(dataPassengers['Passenger ID'].unique()) #what unique values in From Airport Acronym column
    end7 = time.time()
    MapSeaborn2 = end7 - start7
    print("Time It Took For Unique Mapping Function from seaborn To Calculate In Seconds: ", MapSeaborn2)
    print("")
    start8 = time.time()
    print(dataPassengers.groupby('Passenger ID').size()) #number of unique values in From Airport Acronym column 
    end8 = time.time()
    ReduceSeaborn2 = end8 - start8
    print("Time It Took For Reducer from seaborn To Calculate In Seconds: ", ReduceSeaborn2)
                                                                                                            
    f3 = plt.figure(figsize=(30,8))
    sns.countplot(dataPassengers['Passenger ID'],label="Count") #displaying bar chart with counts of each unique value
    file_object.close()
    
    
    #bar chart with execution times
    f4 = plt.figure(figsize=(20,8))
    N = 4
    All_Mapper = (0.00099, 0.00199, 0.00200, 0.00199)
    All_Reducer = (0.00099, 0.00297, 0.00198, 0.00297)

    ind = np.arange(N) 
    width = 0.35       
    plt.bar(ind, All_Mapper, width, label='Mapping Time')
    plt.bar(ind + width, All_Reducer, width,
    label='Reducing Time')

    plt.ylabel('Time To Execute  (Seconds)')
    plt.title('Averages Of Time Taken To Execute MapReduce Functions')

    plt.xticks(ind + width / 2, ('My MapReduce Function Task 1', 'My MapReduce Function Task 2', 'Seaborn Unique MapReduce Function Task 1', 'Seaborn Unique MapReduce Function Task 2'))
    plt.legend(loc='best')
    plt.show()
    
        #second bar chart with execution times that uses live values, can be a bit buggy as some time the timers show 0 seconds for no reason
    f5 = plt.figure(figsize=(20,8))
    N = 4
    All_Mapper = (Map1, Map2, MapSeaborn1, MapSeaborn2)
    All_Reducer = (Reduce1, Reduce2, ReduceSeaborn1, ReduceSeaborn2)

    ind = np.arange(N) 
    width = 0.35       
    plt.bar(ind, All_Mapper, width, label='Mapping Time')
    plt.bar(ind + width, All_Reducer, width,
    label='Reducing Time')

    plt.ylabel('Time To Execute  (Seconds)')
    plt.title('Averages Of Time Taken To Execute MapReduce Functions')

    plt.xticks(ind + width / 2, ('My MapReduce Function Task 1', 'My MapReduce Function Task 2', 'Seaborn Unique MapReduce Function Task 1', 'Seaborn Unique MapReduce Function Task 2'))
    plt.legend(loc='best')
    plt.show()
# Out:
# Displaying Passengers Data:
#     Passenger ID Flight ID From Airport Acronym Destination Airport Acronym  \
# 0     UES9151GS5  SQU6245R                  DEN                         FRA
# 1     UES9151GS5  XXQ4064B                  JFK                         FRA
# 2     EZC9678QI6  SOH3431A                  ORD                         MIA
# 3     ONL0812DH1  SOH3431A                  ORD                         MIA
# 4     CYJ0225CH1  PME8178S                  DEN                         PEK
# ..           ...       ...                  ...                         ...
# 495   BWI0520BG6  BER7172M                  KUL                         LAS
# 496   LLZ3798PE3  EWH6301Y                  CAN                         DFW
# 497   KKP5277HZ7  KJR6646J                  IAH                         BKK
# 498   JJM4724RF7  XXQ4064B                  JFK                         FRA
# 499   SJD8775RZ4  WSK1289Z                  CLT                         DEN
#
#      Departure Time (GMT)  Total Flight time (Mins)
# 0              1420564460                      1049
# 1              1420563917                       802
# 2              1420563649                       250
# 3              1420563649                       250
# 4              1420564409                      1322
# ..                    ...                       ...
# 495            1420565167                      1848
# 496            1420564967                      1683
# 497            1420565203                      1928
# 498            1420563917                       802
# 499            1420563542                       278
#
# [500 rows x 6 columns]
# Displaying Airports Data:
#               Airport Airport Acronym   Latitude   Longitude
# 0             ATLANTA             ATL  33.636719  -84.428067
# 1             BEIJING             PEK  40.080111  116.584556
# 2              LONDON             LHR  51.477500   -0.461389
# 3             CHICAGO             ORD  41.978603  -87.904842
# 4               TOKYO             HND  35.552258  139.779694
# 5         LOS ANGELES             LAX  33.942536 -118.408075
# 6               PARIS             CDG  49.012779    2.550000
# 7   DALLAS/FORT WORTH             DFW  32.896828  -97.037997
# 8           FRANKFURT             FRA  50.026421    8.543125
# 9           HONG KONG             HKG  22.308919  113.914603
# 10             DENVER             DEN  39.861656 -104.673178
# 11              DUBAI             DXB  25.252778   55.364444
# 12            JAKARTA             CGK  -6.125567  106.655897
# 13          AMSTERDAM             AMS  52.308613    4.763889
# 14             MADRID             MAD  40.493556   -3.566764
# 15            BANGKOK             BKK  13.681108  100.747283
# 16           NEW YORK             JFK  40.639751  -73.778925
# 17          SINGAPORE             SIN   1.350189  103.994433
# 18          GUANGZHOU             CAN  23.392436  113.298786
# 19          LAS VEGAS             LAS  36.080056 -115.152250
# 20           SHANGHAI             PVG  31.143378  121.805214
# 21      SAN FRANCISCO             SFO  37.618972 -122.374889
# 22            PHOENIX             PHX  33.434278 -112.011583
# 23            HOUSTON             IAH  29.984433  -95.341442
# 24          CHARLOTTE             CLT  35.214000  -80.943139
# 25              MIAMI             MIA  25.793250  -80.290556
# 26             MUNICH             MUC  48.353783   11.786086
# 27       KUALA LUMPUR             KUL   2.745578  101.709917
# 28               ROME             FCO  41.804475   12.250797
# 29           ISTANBUL             IST  40.976922   28.814606
#  Airport Acronym Column:
#  0      DEN
# 1      JFK
# 2      ORD
# 3      ORD
# 4      DEN
#       ...
# 495    KUL
# 496    CAN
# 497    IAH
# 498    JFK
# 499    CLT
# Name: From Airport Acronym, Length: 500, dtype: object
#
#  Passengers ID Column:
#  0      UES9151GS5
# 1      UES9151GS5
# 2      EZC9678QI6
# 3      ONL0812DH1
# 4      CYJ0225CH1
#           ...
# 495    BWI0520BG6
# 496    LLZ3798PE3
# 497    KKP5277HZ7
# 498    JJM4724RF7
# 499    SJD8775RZ4
# Name: Passenger ID, Length: 500, dtype: object
#
#  All Individual Values Found In List:
#  ['AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'AMS 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'ATL 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'BKK 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CAN 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CDG 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CGK 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'CLT 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DEN 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'DFW 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'FCO 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'HND 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'IAH 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'JFK 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'KUL 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LAS 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'LHR 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MAD 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MIA 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'MUC 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'ORD 1', 'O ...
#
# Time It Took For Mapper Function To Calculate In Seconds:  0.000993967056274414
#
#  Final Unique Values List:
#  ['AMS 1', 'ATL 1', 'BKK 1', 'CAN 1', 'CDG 1', 'CGK 1', 'CLT 1', 'DEN 1', 'DFW 1', 'FCO 1', 'HND 1', 'IAH 1', 'JFK 1', 'KUL 1', 'LAS 1', 'LHR 1', 'MAD 1', 'MIA 1', 'MUC 1', 'ORD 1', 'PEK 1', 'PVG 1']
#
#  Final Unique Values List Length:
#  22
#
#  Final Reduced List Of All Unique Values And The Number Of Each One:
#
# AMS:15
# ATL:36
# BKK:17
# CAN:37
# CDG:21
# CGK:27
# CLT:21
# DEN:46
# DFW:11
# FCO:15
# HND:13
# IAH:37
# JFK:25
# KUL:33
# LAS:17
# LHR:25
# MAD:13
# MIA:11
# MUC:14
# ORD:33
# PEK:13
# PVG:20
# Time It Took For Reducer Function To Calculate In Seconds:  0.0019843578338623047
#
#
#
#  All Individual Values Found In List:
#  ['BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'BWI0520BG6 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CDC0302NN5 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CKZ3132BR4 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CXN7304ER2 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'CYJ0225CH1 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'DAZ3029XA0 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EDV2089LK5 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'EZC9678QI6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HCA3158QA6 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'HGO4350KK1 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'IEG9308EA5 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JBE2302VO4 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'JJM4724RF7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'KKP5277HZ7 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1', 'LLZ3798PE3 1' ...
#
# Time It Took For Mapper Function To Calculate In Seconds:  0.004971027374267578
#
#  Final Unique Values List:
#  ['BWI0520BG6 1', 'CDC0302NN5 1', 'CKZ3132BR4 1', 'CXN7304ER2 1', 'CYJ0225CH1 1', 'DAZ3029XA0 1', 'EDV2089LK5 1', 'EZC9678QI6 1', 'HCA3158QA6 1', 'HGO4350KK1 1', 'IEG9308EA5 1', 'JBE2302VO4 1', 'JJM4724RF7 1', 'KKP5277HZ7 1', 'LLZ3798PE3 1', 'MXU9187YC7 1', 'ONL0812DH1 1', 'PAJ3974RK1 1', 'PIT2755XC1 1', 'POP2875LH3 1', 'PUD8209OG3 1', 'SJD8775RZ4 1', 'SPR4484HA6 1', 'UES9151GS5 1', 'UMH6360YP0 1', 'VZY2993ME1 1', 'WBE6935NU3 1', 'WTC9125IE5 1', 'WYU2010YH8 1', 'XFG5747ZT9 1', 'YMH6360YP0 1']
#
#  Final Unique Values List Length:
#  31
#
#  Final Reduced List Of All Unique Values And The Number Of Each One:
#
# BWI0520BG6:23
# CDC0302NN5:12
# CKZ3132BR4:19
# CXN7304ER2:17
# CYJ0225CH1:11
# DAZ3029XA0:23
# EDV2089LK5:13
# EZC9678QI6:21
# HCA3158QA6:21
# HGO4350KK1:18
# IEG9308EA5:10
# JBE2302VO4:16
# JJM4724RF7:21
# KKP5277HZ7:11
# LLZ3798PE3:16
# MXU9187YC7:14
# ONL0812DH1:12
# PAJ3974RK1:10
# PIT2755XC1:8
# POP2875LH3:19
# PUD8209OG3:23
# SJD8775RZ4:16
# SPR4484HA6:23
# UES9151GS5:25
# UMH6360YP0:1
# VZY2993ME1:16
# WBE6935NU3:19
# WTC9125IE5:14
# WYU2010YH8:19
# XFG5747ZT9:13
# YMH6360YP0:16
#
# Time It Took For Reducer Function To Calculate In Seconds:  0.002977609634399414
#
#  using seaborn unique to cross reference with own created map reduce program:
#
# ['DEN' 'JFK' 'ORD' 'KUL' 'MAD' 'LHR' 'CGK' 'MUC' 'AMS' 'DFW' 'MIA' 'CDG'
#  'CAN' 'IAH' 'LAS' 'CLT' 'ATL' 'PVG' 'FCO' 'BKK' 'PEK' 'HND']
# Time It Took For Unique Function Mapping from seaborn To Calculate In Seconds:  0.002989053726196289
#
# From Airport Acronym
# AMS    15
# ATL    36
# BKK    17
# CAN    37
# CDG    21
# CGK    27
# CLT    21
# DEN    46
# DFW    11
# FCO    15
# HND    13
# IAH    37
# JFK    25
# KUL    33
# LAS    17
# LHR    25
# MAD    13
# MIA    11
# MUC    14
# ORD    33
# PEK    13
# PVG    20
# dtype: int64
# Time It Took For Reducer from seaborn To Calculate In Seconds:  0.011909008026123047
# C:\Users\44739\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ['UES9151GS5' 'EZC9678QI6' 'ONL0812DH1' 'CYJ0225CH1' 'POP2875LH3'
#  'WTC9125IE5' 'EDV2089LK5' 'HCA3158QA6' 'YMH6360YP0' 'PUD8209OG3'
#  'PAJ3974RK1' 'WYU2010YH8' 'JJM4724RF7' 'MXU9187YC7' 'HGO4350KK1'
#  'BWI0520BG6' 'JBE2302VO4' 'DAZ3029XA0' 'PIT2755XC1' 'CKZ3132BR4'
#  'CXN7304ER2' 'WBE6935NU3' 'IEG9308EA5' 'SJD8775RZ4' 'CDC0302NN5'
#  'KKP5277HZ7' 'SPR4484HA6' 'VZY2993ME1' 'LLZ3798PE3' 'XFG5747ZT9'
#  'UMH6360YP0']
# Time It Took For Unique Mapping Function from seaborn To Calculate In Seconds:  0.0009937286376953125
#
# Passenger ID
# BWI0520BG6    23
# CDC0302NN5    12
# CKZ3132BR4    19
# CXN7304ER2    17
# CYJ0225CH1    11
# DAZ3029XA0    23
# EDV2089LK5    13
# EZC9678QI6    21
# HCA3158QA6    21
# HGO4350KK1    18
# IEG9308EA5    10
# JBE2302VO4    16
# JJM4724RF7    21
# KKP5277HZ7    11
# LLZ3798PE3    16
# MXU9187YC7    14
# ONL0812DH1    12
# PAJ3974RK1    10
# PIT2755XC1     8
# POP2875LH3    19
# PUD8209OG3    23
# SJD8775RZ4    16
# SPR4484HA6    23
# UES9151GS5    25
# UMH6360YP0     1
# VZY2993ME1    16
# WBE6935NU3    19
# WTC9125IE5    14
# WYU2010YH8    19
# XFG5747ZT9    13
# YMH6360YP0    16
# dtype: int64
# Time It Took For Reducer from seaborn To Calculate In Seconds:  0.0019865036010742188
# C:\Users\44739\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
